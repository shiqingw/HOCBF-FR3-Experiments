# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

plt.rcParams['font.family'] = 'serif'
plt.rcParams.update({"text.usetex": True,
                        "text.latex.preamble": r"\usepackage{amsmath}"})
plt.rcParams.update({'pdf.fonttype': 42})

# %%
# load data
folder = "exp3_results"
exp_no_circ = "no_circ_2024-08-23-17-26-37"
file = 'data.pickle'
with open(folder + '/' + exp_no_circ + '/' + file, 'rb') as f:
    data_no_circ = pickle.load(f)

# %%
print(data_no_circ.keys())
# Out:
# dict_keys(['q', 'dq', 'tau', 'all_h', 'is_flying', 'ball_center', 'ball_vel', 'time_per_loop'])

# %%
t = np.cumsum(data_no_circ['time_per_loop'])
dq = np.array(data_no_circ["dq"])
dq_norm = np.linalg.norm(dq, axis=1)
start_idx_1 = np.where((dq_norm > 0.05) & (t > 11))[0][0]
if "is_flying" in data_no_circ:
    is_flying = np.array(data_no_circ["is_flying"])
    start_idx_2 = np.where(is_flying == 1.0)[0][0]
else:
    start_idx_2 = len(t)
start_idx = max(start_idx_1, start_idx_2)
end_idx = np.where((dq_norm > 0.05) & (t > 11))[0][-1]

# %%
all_h = np.array(data_no_circ["all_h"])
fig, ax = plt.subplots(figsize=(5,4), frameon=True)
label_fs = 20
tick_fs = 20
legend_fs = 20
linewidth = 3

plt.plot(t, np.min(all_h, axis=1), linewidth=linewidth)
plt.hlines(0, t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], np.min(np.min(all_h, axis=1)), np.max(np.min(all_h, axis=1)), colors='g', linestyles='dashed')
plt.vlines(t[end_idx], np.min(np.min(all_h, axis=1)), np.max(np.min(all_h, axis=1)), colors='r', linestyles='dashed')

# %%
h_picked = all_h[start_idx:end_idx,0:int(all_h.shape[1]/2)]
t_picked = t[start_idx:end_idx] - t[start_idx]

fig, ax = plt.subplots(figsize=(5,4), frameon=True)
label_fs = 20
tick_fs = 20
legend_fs = 20
linewidth = 3

plt.plot(t_picked, np.min(h_picked, axis=1), linewidth=linewidth)
plt.hlines(0, t_picked[0], t_picked[-1], colors='k', linestyles='dashed', linewidth=linewidth)

plt.xlabel('$t$', fontsize=label_fs)
plt.ylabel('$\min(h_1, ..., h_K)$', fontsize=label_fs)
plt.xticks(fontsize = tick_fs)
plt.yticks(fontsize = tick_fs)
plt.tight_layout()
plt.savefig(folder + '/' + exp_no_circ + '/cbf_no_circ.pdf')

# %%
print(np.min(h_picked))
# Out:
# 7.377899641015632

# %%
dq = np.array(data_no_circ['dq'])
dq_lb = np.array([-2.1750, -2.1750, -2.1750, -2.1750, -2.6100, -2.6100, -2.6100])
dq_ub = np.array([2.1750, 2.1750, 2.1750, 2.1750, 2.6100, 2.6100, 2.6100])

plt.plot(t, dq[:,0], linewidth=linewidth)
plt.hlines(dq_lb[0], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[0], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[0], dq_ub[0], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[0], dq_ub[0], colors='r', linestyles='dashed')

# %%
dq = np.array(data_no_circ['dq'])
plt.plot(t, dq[:,1], linewidth=linewidth)
plt.hlines(dq_lb[1], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[1], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[1], dq_ub[1], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[1], dq_ub[1], colors='r', linestyles='dashed')

# %%
dq = np.array(data_no_circ['dq'])
plt.plot(t, dq[:,2], linewidth=linewidth)
plt.hlines(dq_lb[2], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[2], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[2], dq_ub[2], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[2], dq_ub[2], colors='r', linestyles='dashed')

# %%
dq = np.array(data_no_circ['dq'])
plt.plot(t, dq[:,3], linewidth=linewidth)
plt.hlines(dq_lb[3], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[3], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[3], dq_ub[3], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[3], dq_ub[3], colors='r', linestyles='dashed')

# %%
dq = np.array(data_no_circ['dq'])
plt.plot(t, dq[:,4], linewidth=linewidth)
plt.hlines(dq_lb[4], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[4], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[4], dq_ub[4], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[4], dq_ub[4], colors='r', linestyles='dashed')

# %%
dq = np.array(data_no_circ['dq'])
plt.plot(t, dq[:,5], linewidth=linewidth)
plt.hlines(dq_lb[5], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[5], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[5], dq_ub[5], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[5], dq_ub[5], colors='r', linestyles='dashed')

# %%
dq = np.array(data_no_circ['dq'])
plt.plot(t, dq[:,6], linewidth=linewidth)
plt.hlines(dq_lb[6], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.hlines(dq_ub[6], t[0], t[-1], colors='k', linestyles='dashed', linewidth=linewidth)
plt.vlines(t[start_idx], dq_lb[6], dq_ub[6], colors='g', linestyles='dashed')
plt.vlines(t[end_idx], dq_lb[6], dq_ub[6], colors='r', linestyles='dashed')

# %%
time_per_loop_list = data_no_circ['time_per_loop']
times = np.cumsum(time_per_loop_list)
time_per_loop_list = np.array(time_per_loop_list)
plt.plot(times, 1/time_per_loop_list)
plt.hlines(0.1, 0, times[-1], colors='r', linestyles='dashed')
print(np.mean(time_per_loop_list))
print(np.percentile(time_per_loop_list, 90))
# Out:
# 0.006184060470629052
# 0.007647848129272461

# %%
plt.hist(time_per_loop_list, bins=20)
np.median(time_per_loop_list)
# Out:
# 0.006037235260009766

# %%
ball_center = np.array(data_no_circ['ball_center'])
plt.plot(t, ball_center[0:len(t),2])
plt.vlines(t[start_idx], 0, 2, colors='g', linestyles='dashed')
plt.vlines(t[end_idx], 0, 2, colors='r', linestyles='dashed')

# %%
ball_vel = np.array(data_no_circ['ball_vel'])
ball_vel_norm = np.linalg.norm(ball_vel, axis=1)
plt.plot(t, ball_vel_norm[0:len(t)])
plt.vlines(t[start_idx], 0, 10, colors='g', linestyles='dashed')
plt.vlines(t[end_idx], 0, 10, colors='r', linestyles='dashed')
print(ball_vel_norm[start_idx])
# Out:
# 2.8757815814263608
